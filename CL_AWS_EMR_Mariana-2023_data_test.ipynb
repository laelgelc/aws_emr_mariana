# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Data extraction solution for Mariana's research project

# %% [markdown]
# ## Extract data with an Amazon EMR Apache Spark cluster

# %% [markdown]
# ## Year 2023 data test

# %% [markdown]
# ### Import the required libraries

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import lower, col, array_contains

# %% [markdown]
# ### Load data into an Amazon EMR EMR Apache Spark DataFrame

# %% [markdown]
# #### Year 2021 sample

# %%
# Set the S3 bucket and folder paths
data_source = '2021_29.json'

# Create a SparkSession
spark = SparkSession.builder.appName('The Twitter Grab Corpus').getOrCreate()

# Read the JSONL files into a DataFrame
#tweets_spark_df = spark.read.json(args.data_source) # RevA parameters
tweets_spark_df = spark.read.option('recursiveFileLookup', 'true').json(data_source) # RevB parameters

# %%
# Show the first few rows of the DataFrame
tweets_spark_df.show()
# Out:
# +------------+-----------+--------------------+------+------------------+------------------------+--------------------+--------------+--------------+---------+------------+----+-------------------+-------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+---------------+----+-----+------------------+-----------+-------------+----------------+--------------------+-----------------------+-----------+-------------+---------+--------------------+--------------------+------------------------------------+-------------+---------+--------------------+
# |contributors|coordinates|          created_at|delete|display_text_range|                entities|   extended_entities|extended_tweet|favorite_count|favorited|filter_level| geo|                 id|             id_str|in_reply_to_screen_name|in_reply_to_status_id|in_reply_to_status_id_str|in_reply_to_user_id|in_reply_to_user_id_str|is_quote_status|lang|place|possibly_sensitive|quote_count|quoted_status|quoted_status_id|quoted_status_id_str|quoted_status_permalink|reply_count|retweet_count|retweeted|    retweeted_status|              source|                                text| timestamp_ms|truncated|                user|
# +------------+-----------+--------------------+------+------------------+------------------------+--------------------+--------------+--------------+---------+------------+----+-------------------+-------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+---------------+----+-----+------------------+-----------+-------------+----------------+--------------------+-----------------------+-----------+-------------+---------+--------------------+--------------------+------------------------------------+-------------+---------+--------------------+
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468193435649|1344908468193435649|                   null|                 null|                     null|               null|                   null|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|  DJタイムまでアーカイブ残してほしい|1609486140665|    false|{false, Wed Dec 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468159823872|1344908468159823872|                   null|                 null|                     null|               null|                   null|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|  お正月なのにMX2さんでアドベンチ...|1609486140657|    false|{false, Mon Nov 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468184961026|1344908468184961026|                   null|                 null|                     null|               null|                   null|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|  ビッグライブメダル300くらいしか...|1609486140663|    false|{false, Wed Mar 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468180942849|1344908468180942849|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://w...|                KC and the Sunshi...|1609486140662|    false|{false, Fri Apr 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468176576512|1344908468176576512|            DM710910xxx|  1344904208064028672|      1344904208064028672|1327402510034763776|    1327402510034763776|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|と、ゼクシィおばさんを見て思う。\...|1609486140661|    false|{false, Sat Nov 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[{[127, 138], pr...|                null|          null|             0|    false|         low|null|1344908468189184000|1344908468189184000|                   null|                 null|                     null|               null|                   null|          false| und| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|                RT @BPBackupTeam1...|1609486140664|    false|{false, Tue Dec 2...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|  {[{[46, 51], 16時半...|                null|          null|             0|    false|         low|null|1344908468172460033|1344908468172460033|                   null|                 null|                     null|               null|                   null|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|               RT @papi_2615: ♚今...|1609486140660|    false|{false, Sat May 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|{[{[35, 40], 뉴이스트...|{[{{null, null, f...|          null|             0|    false|         low|null|1344908468172464128|1344908468172464128|                   null|                 null|                     null|               null|                   null|          false|  ko| null|             false|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Thu ...|<a href="http://t...|                RT @DEAR_MY_AUGUS...|1609486140660|    false|{false, Thu Dec 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|           [9, 21]|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468176605186|1344908468176605186|                Poijohn|  1344883345335803908|      1344883345335803908|           27192330|               27192330|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|        @Poijohn それな、バチボコ...|1609486140661|    false|{false, Sat Jan 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], [{null, null...|{[{null, null, pi...|          null|             0|    false|         low|null|1344908468197576709|1344908468197576709|                   null|                 null|                     null|               null|                   null|          false|  ja| null|             false|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Thu ...|<a href="https://...|            RT @arabaki: 見た目が...|1609486140666|    false|{false, Thu Feb 2...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], [{{null, nul...|{[{{null, null, f...|          null|             0|    false|         low|null|1344908468164050944|1344908468164050944|                   null|                 null|                     null|               null|                   null|          false|  en| null|             false|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|                RT @LHCFEED: THIS...|1609486140658|    false|{false, Tue Aug 2...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468180815872|1344908468180815872|                   null|                 null|                     null|               null|                   null|          false|  th| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|                RT @rubyjennp: อ๋...|1609486140662|    false|{false, Mon Jul 2...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468176605185|1344908468176605185|                   null|                 null|                     null|               null|                   null|          false|  th| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Thu ...|<a href="http://t...|                RT @yoxrgravity: ...|1609486140661|    false|{false, Sun Jul 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468189233153|1344908468189233153|                   null|                 null|                     null|               null|                   null|          false|  th| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|                RT @SoshiLightSti...|1609486140664|    false|{false, Mon Jun 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|          [26, 28]|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468193382401|1344908468193382401|            AbuKyungsoo|  1344898404317499397|      1344898404317499397|1298638067943616513|    1298638067943616513|          false| und| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|                @AbuKyungsoo @rai...|1609486140665|    false|{false, Tue Jul 1...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|  {[{[30, 33], 웬디}]...|{[{null, null, pi...|          null|             0|    false|         low|null|1344908468176601091|1344908468176601091|                   null|                 null|                     null|               null|                   null|          false|  ko| null|             false|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|                RT @todayis__wend...|1609486140661|    false|{false, Wed Aug 0...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468193546240|1344908468193546240|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|                id fuck a man who...|1609486140665|    false|{false, Mon Aug 0...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468197629952|1344908468197629952|                   null|                 null|                     null|               null|                   null|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|                RT @ars_sakuraba8...|1609486140666|    false|{false, Fri Jun 2...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], [{null, null...|{[{null, null, pi...|          null|             0|    false|         low|null|1344908468184961024|1344908468184961024|                   null|                 null|                     null|               null|                   null|          false|  ja| null|             false|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Wed ...|<a href="https://...|                RT @09ra_19ra: pi...|1609486140663|    false|{false, Fri Feb 0...|
# |        null|       null|Fri Jan 01 07:29:...|  null|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1344908468197629953|1344908468197629953|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="https://...|                33 minutes left o...|1609486140666|    false|{false, Mon Sep 0...|
# +------------+-----------+--------------------+------+------------------+------------------------+--------------------+--------------+--------------+---------+------------+----+-------------------+-------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+---------------+----+-----+------------------+-----------+-------------+----------------+--------------------+-----------------------+-----------+-------------+---------+--------------------+--------------------+------------------------------------+-------------+---------+--------------------+
# only showing top 20 rows

# %%
# Show the quantity of columns of the DataFrame
len(tweets_spark_df.columns)
# Out:
# 37

# %%
# Show the quantity of rows (tweets) of the DataFrame
tweets_spark_df.count()
# Out:
# 3480

# %% [markdown]
# ### Filter the dataframe

# %%
# Define the list of hashtags for DataFrame filtering
hashtags = [
    'acolhimento', 
    'Acolhimento', 
    'ACOLHIMENTO', 
    'aporofobia', 
    'Aporofobia', 
    'APOROFOBIA', 
    'brasilvaivirarvenezuela', 
    'Brasilvaivirarvenezuela', 
    'BrasilVaiVirarVenezuela', 
    'BRASILVAIVIRARVENEZUELA', 
    'crisehumanitária', 
    'Crisehumanitária', 
    'CriseHumanitária', 
    'CRISEHUMANITÁRIA', 
    'crisevenezuelana', 
    'Crisevenezuelana', 
    'CriseVenezuelana', 
    'CRISEVENEZUELANA', 
    'Discriminação', 
    'discriminação', 
    'DISCRIMINAÇÃO', 
    'estereótipo', 
    'Estereótipo', 
    'ESTEREÓTIPO', 
    'fronteira', 
    'Fronteira', 
    'FRONTEIRA', 
    'migrantes', 
    'Migrantes', 
    'MIGRANTES', 
    'preconceito', 
    'Preconceito', 
    'PRECONCEITO', 
    'refugiados', 
    'Refugiados', 
    'REFUGIADOS', 
    'roraizuela', 
    'Roraizuela', 
    'RORAIZUELA', 
    'venebrasil', 
    'Venebrasil', 
    'VeneBrasil', 
    'VENEBRASIL', 
    'venezuelanosnobrasil', 
    'Venezuelanosnobrasil', 
    'VenezuelanosNoBrasil', 
    'VENEZUELANOSNOBRASIL', 
    'venezuraima', 
    'Venezuraima', 
    'VENEZURAIMA', 
    'violência', 
    'Violência', 
    'VIOLÊNCIA', 
    'xenofobia', 
    'Xenofobia', 
    'XENOFOBIA'
]

expressions = [
    'ameaça', 
    'aporofobia', 
    'carga', 
    'conflito', 
    'crise', 
    'delinquência', 
    'desconfiança', 
    'desemprego', 
    'desigualdade', 
    'desordem', 
    'direitos', 
    'discriminação', 
    'estigma', 
    'estrangeiro', 
    'exclusão', 
    'fronteira',  
    'hostilidade', 
    'humanitário', 
    'identidade', 
    'inferior', 
    'intolerância', 
    'invasão', 
    'marginal', 
    'perigo', 
    'preconceito', 
    'problema', 
    'racismo', 
    'refugiada', 
    'refugiado', 
    'refugiados', 
    'rejeição', 
    'roraizuela', 
    'venebrasil', 
    'venezuela', 
    'venezuelana', 
    'venezuelanas', 
    'venezuelano', 
    'venezuelanos', 
    'venezuraima', 
    'violência', 
    'xenofobia'
]

# Create a filtered DataFrame
filtered_tweets_spark_df = tweets_spark_df.filter(
    array_contains('entities.hashtags.text', hashtags[0]) |\
    array_contains('entities.hashtags.text', hashtags[1]) |\
    array_contains('entities.hashtags.text', hashtags[2]) |\
    array_contains('entities.hashtags.text', hashtags[3]) |\
    array_contains('entities.hashtags.text', hashtags[4]) |\
    array_contains('entities.hashtags.text', hashtags[5]) |\
    array_contains('entities.hashtags.text', hashtags[6]) |\
    array_contains('entities.hashtags.text', hashtags[7]) |\
    array_contains('entities.hashtags.text', hashtags[8]) |\
    array_contains('entities.hashtags.text', hashtags[9]) |\
    array_contains('entities.hashtags.text', hashtags[10]) |\
    array_contains('entities.hashtags.text', hashtags[11]) |\
    array_contains('entities.hashtags.text', hashtags[12]) |\
    array_contains('entities.hashtags.text', hashtags[13]) |\
    array_contains('entities.hashtags.text', hashtags[14]) |\
    array_contains('entities.hashtags.text', hashtags[15]) |\
    array_contains('entities.hashtags.text', hashtags[16]) |\
    array_contains('entities.hashtags.text', hashtags[17]) |\
    array_contains('entities.hashtags.text', hashtags[18]) |\
    array_contains('entities.hashtags.text', hashtags[19]) |\
    array_contains('entities.hashtags.text', hashtags[20]) |\
    array_contains('entities.hashtags.text', hashtags[21]) |\
    array_contains('entities.hashtags.text', hashtags[22]) |\
    array_contains('entities.hashtags.text', hashtags[23]) |\
    array_contains('entities.hashtags.text', hashtags[24]) |\
    array_contains('entities.hashtags.text', hashtags[25]) |\
    array_contains('entities.hashtags.text', hashtags[26]) |\
    array_contains('entities.hashtags.text', hashtags[27]) |\
    array_contains('entities.hashtags.text', hashtags[28]) |\
    array_contains('entities.hashtags.text', hashtags[29]) |\
    array_contains('entities.hashtags.text', hashtags[30]) |\
    array_contains('entities.hashtags.text', hashtags[31]) |\
    array_contains('entities.hashtags.text', hashtags[32]) |\
    array_contains('entities.hashtags.text', hashtags[33]) |\
    array_contains('entities.hashtags.text', hashtags[34]) |\
    array_contains('entities.hashtags.text', hashtags[35]) |\
    array_contains('entities.hashtags.text', hashtags[36]) |\
    array_contains('entities.hashtags.text', hashtags[37]) |\
    array_contains('entities.hashtags.text', hashtags[38]) |\
    array_contains('entities.hashtags.text', hashtags[39]) |\
    array_contains('entities.hashtags.text', hashtags[40]) |\
    array_contains('entities.hashtags.text', hashtags[41]) |\
    array_contains('entities.hashtags.text', hashtags[42]) |\
    array_contains('entities.hashtags.text', hashtags[43]) |\
    array_contains('entities.hashtags.text', hashtags[44]) |\
    array_contains('entities.hashtags.text', hashtags[45]) |\
    array_contains('entities.hashtags.text', hashtags[46]) |\
    array_contains('entities.hashtags.text', hashtags[47]) |\
    array_contains('entities.hashtags.text', hashtags[48]) |\
    array_contains('entities.hashtags.text', hashtags[49]) |\
    array_contains('entities.hashtags.text', hashtags[50]) |\
    array_contains('entities.hashtags.text', hashtags[51]) |\
    array_contains('entities.hashtags.text', hashtags[52]) |\
    array_contains('entities.hashtags.text', hashtags[53]) |\
    array_contains('entities.hashtags.text', hashtags[54]) |\
    array_contains('entities.hashtags.text', hashtags[55]) |\
    lower(col('text')).contains(expressions[0]) |\
    lower(col('text')).contains(expressions[1]) |\
    lower(col('text')).contains(expressions[2]) |\
    lower(col('text')).contains(expressions[3]) |\
    lower(col('text')).contains(expressions[4]) |\
    lower(col('text')).contains(expressions[5]) |\
    lower(col('text')).contains(expressions[6]) |\
    lower(col('text')).contains(expressions[7]) |\
    lower(col('text')).contains(expressions[8]) |\
    lower(col('text')).contains(expressions[9]) |\
    lower(col('text')).contains(expressions[10]) |\
    lower(col('text')).contains(expressions[11]) |\
    lower(col('text')).contains(expressions[12]) |\
    lower(col('text')).contains(expressions[13]) |\
    lower(col('text')).contains(expressions[14]) |\
    lower(col('text')).contains(expressions[15]) |\
    lower(col('text')).contains(expressions[16]) |\
    lower(col('text')).contains(expressions[17]) |\
    lower(col('text')).contains(expressions[18]) |\
    lower(col('text')).contains(expressions[19]) |\
    lower(col('text')).contains(expressions[20]) |\
    lower(col('text')).contains(expressions[21]) |\
    lower(col('text')).contains(expressions[22]) |\
    lower(col('text')).contains(expressions[23]) |\
    lower(col('text')).contains(expressions[24]) |\
    lower(col('text')).contains(expressions[25]) |\
    lower(col('text')).contains(expressions[26]) |\
    lower(col('text')).contains(expressions[27]) |\
    lower(col('text')).contains(expressions[28]) |\
    lower(col('text')).contains(expressions[29]) |\
    lower(col('text')).contains(expressions[30]) |\
    lower(col('text')).contains(expressions[31]) |\
    lower(col('text')).contains(expressions[32]) |\
    lower(col('text')).contains(expressions[33]) |\
    lower(col('text')).contains(expressions[34]) |\
    lower(col('text')).contains(expressions[35]) |\
    lower(col('text')).contains(expressions[36]) |\
    lower(col('text')).contains(expressions[37]) |\
    lower(col('text')).contains(expressions[38]) |\
    lower(col('text')).contains(expressions[39]) |\
    lower(col('text')).contains(expressions[40])
)

# %% [markdown]
# #### Year 2022 sample

# %%
# Set the S3 bucket and folder paths
data_source = '2022_20220101000000.json'

# Create a SparkSession
spark = SparkSession.builder.appName('The Twitter Grab Corpus').getOrCreate()

# Read the JSONL files into a DataFrame
#tweets_spark_df = spark.read.json(args.data_source) # RevA parameters
tweets_spark_df = spark.read.option('recursiveFileLookup', 'true').json(data_source) # RevB parameters

# %%
# Show the first few rows of the DataFrame
tweets_spark_df.show()
# Out:
# +------------+-----------+--------------------+------------------+------------------------+--------------------+--------------+--------------+---------+------------+----+-------------------+-------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+---------------+----+-----+------------------+-----------+-------------+----------------+--------------------+-----------------------+-----------+-------------+---------+--------------------+--------------------+-------------------------------------+-------------+---------+--------------------+
# |contributors|coordinates|          created_at|display_text_range|                entities|   extended_entities|extended_tweet|favorite_count|favorited|filter_level| geo|                 id|             id_str|in_reply_to_screen_name|in_reply_to_status_id|in_reply_to_status_id_str|in_reply_to_user_id|in_reply_to_user_id_str|is_quote_status|lang|place|possibly_sensitive|quote_count|quoted_status|quoted_status_id|quoted_status_id_str|quoted_status_permalink|reply_count|retweet_count|retweeted|    retweeted_status|              source|                                 text| timestamp_ms|truncated|                user|
# +------------+-----------+--------------------+------------------+------------------------+--------------------+--------------+--------------+---------+------------+----+-------------------+-------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+---------------+----+-----+------------------+-----------+-------------+----------------+--------------------+-----------------------+-----------+-------------+---------+--------------------+--------------------+-------------------------------------+-------------+---------+--------------------+
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067019405123591|1477067019405123591|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|                 RT @adambvary: I ...|1640995194661|    false|{false, Thu Mar 3...|
# |        null|       null|Fri Dec 31 23:59:...|          [14, 19]|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067019388596225|1477067019388596225|           888toyota4wd|  1477063846481526786|      1477063846481526786|1059930127230877696|    1059930127230877696|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|             @888toyota4wd 遠すぎる😭|1640995194657|    false|{false, Sun Aug 1...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067019405373441|1477067019405373441|                   null|                 null|                     null|               null|                   null|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|福袋でも買いに行こうかと思ったけど...|1640995194661|    false|{false, Sun Aug 0...|
# |        null|       null|Fri Dec 31 23:59:...|          [15, 44]|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067019396677632|1477067019396677632|          brownandbella|  1477065953405976582|      1477065953405976582|           79282617|               79282617|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://w...|                 @brownandbella im...|1640995194659|    false|{false, Fri Sep 1...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023595180032|1477067023595180032|            BucannonXC5|  1477066840937406466|      1477066840937406466|           32783612|               32783612|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="https://...|                 No. 4 (tied) Frui...|1640995195660|    false|{false, Sat Apr 1...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023587102720|1477067023587102720|                   null|                 null|                     null|               null|                   null|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|                 RT @cupula_cupula...|1640995195658|    false|{false, Mon May 0...|
# |        null|       null|Fri Dec 31 23:59:...|          [16, 32]|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023603875840|1477067023603875840|         Setuna__kokoro|  1477063611784876034|      1477063611784876034|1250227038025220096|    1250227038025220096|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|                @Setuna__kokoro お...|1640995195662|    false|{false, Thu Jun 1...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023599419395|1477067023599419395|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="https://...|                 RT @catoletters: ...|1640995195661|    false|{false, Sat Jan 2...|
# |        null|       null|Fri Dec 31 23:59:...|           [9, 28]|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023599357955|1477067023599357955|                666TOJI|  1477022504338219012|      1477022504338219012|1405925713287467010|    1405925713287467010|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|                 @666TOJI WOO HAPP...|1640995195661|    false|{false, Thu Oct 1...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023599296512|1477067023599296512|                   null|                 null|                     null|               null|                   null|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Thu ...|<a href="http://t...|                 RT @BoyMamaaaa: I...|1640995195661|    false|{false, Sat Oct 0...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], [{null, null...|{[{null, null, pi...|          null|             0|    false|         low|null|1477067023616077825|1477067023616077825|                   null|                 null|                     null|               null|                   null|          false|  th| null|             false|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Thu ...|<a href="http://t...|                 RT @mintitapoppy:...|1640995195665|    false|{false, Mon Oct 1...|
# |        null|       null|Fri Dec 31 23:59:...|              null|{[{[69, 74], 阿澄佳奈...|                null|          null|             0|    false|         low|null|1477067023608086528|1477067023608086528|                   null|                 null|                     null|               null|                   null|          false|  ja| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|                 RT @GuardianTales...|1640995195663|    false|{false, Wed Jan 2...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], [{...|                null|          null|             0|    false|         low|null|1477067023607869442|1477067023607869442|                   null|                 null|                     null|               null|                   null|          false|  pt| null|             false|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://w...|                 o seu perfil foi ...|1640995195663|    false|{false, Sun Aug 2...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], [{null, null...|{[{null, null, pi...|          null|             0|    false|         low|null|1477067023591284738|1477067023591284738|                   null|                 null|                     null|               null|                   null|          false|  ja| null|             false|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="https://...|              RT @yomosaka: 描き納...|1640995195659|    false|{false, Mon Mar 2...|
# |        null|       null|Fri Dec 31 23:59:...|          [10, 22]|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023612100610|1477067023612100610|               Kaxhigga|  1477066933799370752|      1477066933799370752|1170369755275907072|    1170369755275907072|          false| und| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="https://...|                 @Kaxhigga NAAAA &...|1640995195664|    false|{false, Sat Jun 0...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023586844678|1477067023586844678|         vwhitlockmusic|  1477066851230392322|      1477066851230392322| 949040615261601794|     949040615261601794|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|                 And just workers ...|1640995195658|    false|{false, Thu Jan 0...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023599423493|1477067023599423493|                   null|                 null|                     null|               null|                   null|          false|  es| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|                 Vamos a ver cuant...|1640995195661|    false|{false, Tue Aug 0...|
# |        null|       null|Fri Dec 31 23:59:...|              null|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023599509514|1477067023599509514|                   null|                 null|                     null|               null|                   null|          false|  ar| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|{null, null, Fri ...|<a href="http://t...|               RT @peace1003: 义无...|1640995195661|    false|{false, Wed May 2...|
# |        null|       null|Fri Dec 31 23:59:...|          [24, 37]|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023586783235|1477067023586783235|           wolfi_______|  1477066942884327424|      1477066942884327424|1109979995206762496|    1109979995206762496|          false|  es| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="https://...|                 @wolfi_______ @0H...|1640995195658|    false|{false, Sun Oct 2...|
# |        null|       null|Fri Dec 31 23:59:...|          [16, 39]|    {[], null, [], []...|                null|          null|             0|    false|         low|null|1477067023599427584|1477067023599427584|         inmortalcrypto|  1477066543049715712|      1477066543049715712|          571771109|              571771109|          false|  en| null|              null|          0|         null|            null|                null|                   null|          0|            0|    false|                null|<a href="http://t...|                 @inmortalcrypto H...|1640995195661|    false|{false, Fri May 0...|
# +------------+-----------+--------------------+------------------+------------------------+--------------------+--------------+--------------+---------+------------+----+-------------------+-------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+---------------+----+-----+------------------+-----------+-------------+----------------+--------------------+-----------------------+-----------+-------------+---------+--------------------+--------------------+-------------------------------------+-------------+---------+--------------------+
# only showing top 20 rows

# %%
# Show the quantity of columns of the DataFrame
len(tweets_spark_df.columns)
# Out:
# 36

# %%
# Show the quantity of rows (tweets) of the DataFrame
tweets_spark_df.count()
# Out:
# 2958

# %% [markdown]
# ### Filter the dataframe

# %%
# Define the list of hashtags for DataFrame filtering
hashtags = [
    'acolhimento', 
    'Acolhimento', 
    'ACOLHIMENTO', 
    'aporofobia', 
    'Aporofobia', 
    'APOROFOBIA', 
    'brasilvaivirarvenezuela', 
    'Brasilvaivirarvenezuela', 
    'BrasilVaiVirarVenezuela', 
    'BRASILVAIVIRARVENEZUELA', 
    'crisehumanitária', 
    'Crisehumanitária', 
    'CriseHumanitária', 
    'CRISEHUMANITÁRIA', 
    'crisevenezuelana', 
    'Crisevenezuelana', 
    'CriseVenezuelana', 
    'CRISEVENEZUELANA', 
    'Discriminação', 
    'discriminação', 
    'DISCRIMINAÇÃO', 
    'estereótipo', 
    'Estereótipo', 
    'ESTEREÓTIPO', 
    'fronteira', 
    'Fronteira', 
    'FRONTEIRA', 
    'migrantes', 
    'Migrantes', 
    'MIGRANTES', 
    'preconceito', 
    'Preconceito', 
    'PRECONCEITO', 
    'refugiados', 
    'Refugiados', 
    'REFUGIADOS', 
    'roraizuela', 
    'Roraizuela', 
    'RORAIZUELA', 
    'venebrasil', 
    'Venebrasil', 
    'VeneBrasil', 
    'VENEBRASIL', 
    'venezuelanosnobrasil', 
    'Venezuelanosnobrasil', 
    'VenezuelanosNoBrasil', 
    'VENEZUELANOSNOBRASIL', 
    'venezuraima', 
    'Venezuraima', 
    'VENEZURAIMA', 
    'violência', 
    'Violência', 
    'VIOLÊNCIA', 
    'xenofobia', 
    'Xenofobia', 
    'XENOFOBIA'
]

expressions = [
    'ameaça', 
    'aporofobia', 
    'carga', 
    'conflito', 
    'crise', 
    'delinquência', 
    'desconfiança', 
    'desemprego', 
    'desigualdade', 
    'desordem', 
    'direitos', 
    'discriminação', 
    'estigma', 
    'estrangeiro', 
    'exclusão', 
    'fronteira',  
    'hostilidade', 
    'humanitário', 
    'identidade', 
    'inferior', 
    'intolerância', 
    'invasão', 
    'marginal', 
    'perigo', 
    'preconceito', 
    'problema', 
    'racismo', 
    'refugiada', 
    'refugiado', 
    'refugiados', 
    'rejeição', 
    'roraizuela', 
    'venebrasil', 
    'venezuela', 
    'venezuelana', 
    'venezuelanas', 
    'venezuelano', 
    'venezuelanos', 
    'venezuraima', 
    'violência', 
    'xenofobia'
]

# Create a filtered DataFrame
filtered_tweets_spark_df = tweets_spark_df.filter(
    array_contains('entities.hashtags.text', hashtags[0]) |\
    array_contains('entities.hashtags.text', hashtags[1]) |\
    array_contains('entities.hashtags.text', hashtags[2]) |\
    array_contains('entities.hashtags.text', hashtags[3]) |\
    array_contains('entities.hashtags.text', hashtags[4]) |\
    array_contains('entities.hashtags.text', hashtags[5]) |\
    array_contains('entities.hashtags.text', hashtags[6]) |\
    array_contains('entities.hashtags.text', hashtags[7]) |\
    array_contains('entities.hashtags.text', hashtags[8]) |\
    array_contains('entities.hashtags.text', hashtags[9]) |\
    array_contains('entities.hashtags.text', hashtags[10]) |\
    array_contains('entities.hashtags.text', hashtags[11]) |\
    array_contains('entities.hashtags.text', hashtags[12]) |\
    array_contains('entities.hashtags.text', hashtags[13]) |\
    array_contains('entities.hashtags.text', hashtags[14]) |\
    array_contains('entities.hashtags.text', hashtags[15]) |\
    array_contains('entities.hashtags.text', hashtags[16]) |\
    array_contains('entities.hashtags.text', hashtags[17]) |\
    array_contains('entities.hashtags.text', hashtags[18]) |\
    array_contains('entities.hashtags.text', hashtags[19]) |\
    array_contains('entities.hashtags.text', hashtags[20]) |\
    array_contains('entities.hashtags.text', hashtags[21]) |\
    array_contains('entities.hashtags.text', hashtags[22]) |\
    array_contains('entities.hashtags.text', hashtags[23]) |\
    array_contains('entities.hashtags.text', hashtags[24]) |\
    array_contains('entities.hashtags.text', hashtags[25]) |\
    array_contains('entities.hashtags.text', hashtags[26]) |\
    array_contains('entities.hashtags.text', hashtags[27]) |\
    array_contains('entities.hashtags.text', hashtags[28]) |\
    array_contains('entities.hashtags.text', hashtags[29]) |\
    array_contains('entities.hashtags.text', hashtags[30]) |\
    array_contains('entities.hashtags.text', hashtags[31]) |\
    array_contains('entities.hashtags.text', hashtags[32]) |\
    array_contains('entities.hashtags.text', hashtags[33]) |\
    array_contains('entities.hashtags.text', hashtags[34]) |\
    array_contains('entities.hashtags.text', hashtags[35]) |\
    array_contains('entities.hashtags.text', hashtags[36]) |\
    array_contains('entities.hashtags.text', hashtags[37]) |\
    array_contains('entities.hashtags.text', hashtags[38]) |\
    array_contains('entities.hashtags.text', hashtags[39]) |\
    array_contains('entities.hashtags.text', hashtags[40]) |\
    array_contains('entities.hashtags.text', hashtags[41]) |\
    array_contains('entities.hashtags.text', hashtags[42]) |\
    array_contains('entities.hashtags.text', hashtags[43]) |\
    array_contains('entities.hashtags.text', hashtags[44]) |\
    array_contains('entities.hashtags.text', hashtags[45]) |\
    array_contains('entities.hashtags.text', hashtags[46]) |\
    array_contains('entities.hashtags.text', hashtags[47]) |\
    array_contains('entities.hashtags.text', hashtags[48]) |\
    array_contains('entities.hashtags.text', hashtags[49]) |\
    array_contains('entities.hashtags.text', hashtags[50]) |\
    array_contains('entities.hashtags.text', hashtags[51]) |\
    array_contains('entities.hashtags.text', hashtags[52]) |\
    array_contains('entities.hashtags.text', hashtags[53]) |\
    array_contains('entities.hashtags.text', hashtags[54]) |\
    array_contains('entities.hashtags.text', hashtags[55]) |\
    lower(col('text')).contains(expressions[0]) |\
    lower(col('text')).contains(expressions[1]) |\
    lower(col('text')).contains(expressions[2]) |\
    lower(col('text')).contains(expressions[3]) |\
    lower(col('text')).contains(expressions[4]) |\
    lower(col('text')).contains(expressions[5]) |\
    lower(col('text')).contains(expressions[6]) |\
    lower(col('text')).contains(expressions[7]) |\
    lower(col('text')).contains(expressions[8]) |\
    lower(col('text')).contains(expressions[9]) |\
    lower(col('text')).contains(expressions[10]) |\
    lower(col('text')).contains(expressions[11]) |\
    lower(col('text')).contains(expressions[12]) |\
    lower(col('text')).contains(expressions[13]) |\
    lower(col('text')).contains(expressions[14]) |\
    lower(col('text')).contains(expressions[15]) |\
    lower(col('text')).contains(expressions[16]) |\
    lower(col('text')).contains(expressions[17]) |\
    lower(col('text')).contains(expressions[18]) |\
    lower(col('text')).contains(expressions[19]) |\
    lower(col('text')).contains(expressions[20]) |\
    lower(col('text')).contains(expressions[21]) |\
    lower(col('text')).contains(expressions[22]) |\
    lower(col('text')).contains(expressions[23]) |\
    lower(col('text')).contains(expressions[24]) |\
    lower(col('text')).contains(expressions[25]) |\
    lower(col('text')).contains(expressions[26]) |\
    lower(col('text')).contains(expressions[27]) |\
    lower(col('text')).contains(expressions[28]) |\
    lower(col('text')).contains(expressions[29]) |\
    lower(col('text')).contains(expressions[30]) |\
    lower(col('text')).contains(expressions[31]) |\
    lower(col('text')).contains(expressions[32]) |\
    lower(col('text')).contains(expressions[33]) |\
    lower(col('text')).contains(expressions[34]) |\
    lower(col('text')).contains(expressions[35]) |\
    lower(col('text')).contains(expressions[36]) |\
    lower(col('text')).contains(expressions[37]) |\
    lower(col('text')).contains(expressions[38]) |\
    lower(col('text')).contains(expressions[39]) |\
    lower(col('text')).contains(expressions[40])
)

# %% [markdown]
# #### Year 2023 sample

# %% [markdown]
# The data corresponding to year 2023 is malformed. While the data samples of year 2021 and 2020 have 37 and 36 columns respectively, the data of year 2023 has only 3 columns, which makes it unsuitable.

# %%
# Set the S3 bucket and folder paths
data_source = '2023_0.json'

# Create a SparkSession
spark = SparkSession.builder.appName('The Twitter Grab Corpus').getOrCreate()

# Read the JSONL files into a DataFrame
#tweets_spark_df = spark.read.json(args.data_source) # RevA parameters
tweets_spark_df = spark.read.option('recursiveFileLookup', 'true').json(data_source) # RevB parameters

# %%
# Show the first few rows of the DataFrame
tweets_spark_df.show()
# Out:
# +--------------------+------+--------------------+
# |                data|errors|            includes|
# +--------------------+------+--------------------+
# |{{null, null}, 83...|  null|{null, null, null...|
# |{{[7_160596835600...|  null|{[{null, 15000, 6...|
# |{{null, null}, 15...|  null|{null, null, null...|
# |{{[3_116075026331...|  null|{[{null, null, 23...|
# |{{null, null}, 16...|  null|{null, null, null...|
# |{{null, null}, 73...|  null|{null, null, null...|
# |{{null, null}, 15...|  null|{null, null, null...|
# |{{[16_16092951206...|  null|{[{null, null, 27...|
# |{{null, null}, 61...|  null|{null, null, null...|
# |{{null, null}, 15...|  null|{null, null, null...|
# |{{null, null}, 88...|  null|{null, null, null...|
# |{{[3_160918518494...|  null|{[{null, null, 11...|
# |{{[3_111192783003...|  null|{[{null, null, 23...|
# |{{null, null}, 15...|  null|{null, null, null...|
# |{{[3_160933860191...|  null|{[{null, null, 28...|
# |{{null, null}, 11...|  null|{null, null, null...|
# |{{[16_16092254162...|  null|{[{null, null, 39...|
# |{{[7_160735398400...|  null|{[{null, 3083, 50...|
# |{{[16_16093272964...|  null|{[{null, null, 49...|
# |{{null, null}, 15...|  null|{null, null, null...|
# +--------------------+------+--------------------+
# only showing top 20 rows

# %%
# Show the quantity of columns of the DataFrame
len(tweets_spark_df.columns)
# Out:
# 3

# %%
# Show the quantity of rows (tweets) of the DataFrame
tweets_spark_df.count()
# Out:
# 2783

# %% [markdown]
# ### Filter the dataframe

# %%
# Define the list of hashtags for DataFrame filtering
hashtags = [
    'acolhimento', 
    'Acolhimento', 
    'ACOLHIMENTO', 
    'aporofobia', 
    'Aporofobia', 
    'APOROFOBIA', 
    'brasilvaivirarvenezuela', 
    'Brasilvaivirarvenezuela', 
    'BrasilVaiVirarVenezuela', 
    'BRASILVAIVIRARVENEZUELA', 
    'crisehumanitária', 
    'Crisehumanitária', 
    'CriseHumanitária', 
    'CRISEHUMANITÁRIA', 
    'crisevenezuelana', 
    'Crisevenezuelana', 
    'CriseVenezuelana', 
    'CRISEVENEZUELANA', 
    'Discriminação', 
    'discriminação', 
    'DISCRIMINAÇÃO', 
    'estereótipo', 
    'Estereótipo', 
    'ESTEREÓTIPO', 
    'fronteira', 
    'Fronteira', 
    'FRONTEIRA', 
    'migrantes', 
    'Migrantes', 
    'MIGRANTES', 
    'preconceito', 
    'Preconceito', 
    'PRECONCEITO', 
    'refugiados', 
    'Refugiados', 
    'REFUGIADOS', 
    'roraizuela', 
    'Roraizuela', 
    'RORAIZUELA', 
    'venebrasil', 
    'Venebrasil', 
    'VeneBrasil', 
    'VENEBRASIL', 
    'venezuelanosnobrasil', 
    'Venezuelanosnobrasil', 
    'VenezuelanosNoBrasil', 
    'VENEZUELANOSNOBRASIL', 
    'venezuraima', 
    'Venezuraima', 
    'VENEZURAIMA', 
    'violência', 
    'Violência', 
    'VIOLÊNCIA', 
    'xenofobia', 
    'Xenofobia', 
    'XENOFOBIA'
]

expressions = [
    'ameaça', 
    'aporofobia', 
    'carga', 
    'conflito', 
    'crise', 
    'delinquência', 
    'desconfiança', 
    'desemprego', 
    'desigualdade', 
    'desordem', 
    'direitos', 
    'discriminação', 
    'estigma', 
    'estrangeiro', 
    'exclusão', 
    'fronteira',  
    'hostilidade', 
    'humanitário', 
    'identidade', 
    'inferior', 
    'intolerância', 
    'invasão', 
    'marginal', 
    'perigo', 
    'preconceito', 
    'problema', 
    'racismo', 
    'refugiada', 
    'refugiado', 
    'refugiados', 
    'rejeição', 
    'roraizuela', 
    'venebrasil', 
    'venezuela', 
    'venezuelana', 
    'venezuelanas', 
    'venezuelano', 
    'venezuelanos', 
    'venezuraima', 
    'violência', 
    'xenofobia'
]

# Create a filtered DataFrame
filtered_tweets_spark_df = tweets_spark_df.filter(
    array_contains('entities.hashtags.text', hashtags[0]) |\
    array_contains('entities.hashtags.text', hashtags[1]) |\
    array_contains('entities.hashtags.text', hashtags[2]) |\
    array_contains('entities.hashtags.text', hashtags[3]) |\
    array_contains('entities.hashtags.text', hashtags[4]) |\
    array_contains('entities.hashtags.text', hashtags[5]) |\
    array_contains('entities.hashtags.text', hashtags[6]) |\
    array_contains('entities.hashtags.text', hashtags[7]) |\
    array_contains('entities.hashtags.text', hashtags[8]) |\
    array_contains('entities.hashtags.text', hashtags[9]) |\
    array_contains('entities.hashtags.text', hashtags[10]) |\
    array_contains('entities.hashtags.text', hashtags[11]) |\
    array_contains('entities.hashtags.text', hashtags[12]) |\
    array_contains('entities.hashtags.text', hashtags[13]) |\
    array_contains('entities.hashtags.text', hashtags[14]) |\
    array_contains('entities.hashtags.text', hashtags[15]) |\
    array_contains('entities.hashtags.text', hashtags[16]) |\
    array_contains('entities.hashtags.text', hashtags[17]) |\
    array_contains('entities.hashtags.text', hashtags[18]) |\
    array_contains('entities.hashtags.text', hashtags[19]) |\
    array_contains('entities.hashtags.text', hashtags[20]) |\
    array_contains('entities.hashtags.text', hashtags[21]) |\
    array_contains('entities.hashtags.text', hashtags[22]) |\
    array_contains('entities.hashtags.text', hashtags[23]) |\
    array_contains('entities.hashtags.text', hashtags[24]) |\
    array_contains('entities.hashtags.text', hashtags[25]) |\
    array_contains('entities.hashtags.text', hashtags[26]) |\
    array_contains('entities.hashtags.text', hashtags[27]) |\
    array_contains('entities.hashtags.text', hashtags[28]) |\
    array_contains('entities.hashtags.text', hashtags[29]) |\
    array_contains('entities.hashtags.text', hashtags[30]) |\
    array_contains('entities.hashtags.text', hashtags[31]) |\
    array_contains('entities.hashtags.text', hashtags[32]) |\
    array_contains('entities.hashtags.text', hashtags[33]) |\
    array_contains('entities.hashtags.text', hashtags[34]) |\
    array_contains('entities.hashtags.text', hashtags[35]) |\
    array_contains('entities.hashtags.text', hashtags[36]) |\
    array_contains('entities.hashtags.text', hashtags[37]) |\
    array_contains('entities.hashtags.text', hashtags[38]) |\
    array_contains('entities.hashtags.text', hashtags[39]) |\
    array_contains('entities.hashtags.text', hashtags[40]) |\
    array_contains('entities.hashtags.text', hashtags[41]) |\
    array_contains('entities.hashtags.text', hashtags[42]) |\
    array_contains('entities.hashtags.text', hashtags[43]) |\
    array_contains('entities.hashtags.text', hashtags[44]) |\
    array_contains('entities.hashtags.text', hashtags[45]) |\
    array_contains('entities.hashtags.text', hashtags[46]) |\
    array_contains('entities.hashtags.text', hashtags[47]) |\
    array_contains('entities.hashtags.text', hashtags[48]) |\
    array_contains('entities.hashtags.text', hashtags[49]) |\
    array_contains('entities.hashtags.text', hashtags[50]) |\
    array_contains('entities.hashtags.text', hashtags[51]) |\
    array_contains('entities.hashtags.text', hashtags[52]) |\
    array_contains('entities.hashtags.text', hashtags[53]) |\
    array_contains('entities.hashtags.text', hashtags[54]) |\
    array_contains('entities.hashtags.text', hashtags[55]) |\
    lower(col('text')).contains(expressions[0]) |\
    lower(col('text')).contains(expressions[1]) |\
    lower(col('text')).contains(expressions[2]) |\
    lower(col('text')).contains(expressions[3]) |\
    lower(col('text')).contains(expressions[4]) |\
    lower(col('text')).contains(expressions[5]) |\
    lower(col('text')).contains(expressions[6]) |\
    lower(col('text')).contains(expressions[7]) |\
    lower(col('text')).contains(expressions[8]) |\
    lower(col('text')).contains(expressions[9]) |\
    lower(col('text')).contains(expressions[10]) |\
    lower(col('text')).contains(expressions[11]) |\
    lower(col('text')).contains(expressions[12]) |\
    lower(col('text')).contains(expressions[13]) |\
    lower(col('text')).contains(expressions[14]) |\
    lower(col('text')).contains(expressions[15]) |\
    lower(col('text')).contains(expressions[16]) |\
    lower(col('text')).contains(expressions[17]) |\
    lower(col('text')).contains(expressions[18]) |\
    lower(col('text')).contains(expressions[19]) |\
    lower(col('text')).contains(expressions[20]) |\
    lower(col('text')).contains(expressions[21]) |\
    lower(col('text')).contains(expressions[22]) |\
    lower(col('text')).contains(expressions[23]) |\
    lower(col('text')).contains(expressions[24]) |\
    lower(col('text')).contains(expressions[25]) |\
    lower(col('text')).contains(expressions[26]) |\
    lower(col('text')).contains(expressions[27]) |\
    lower(col('text')).contains(expressions[28]) |\
    lower(col('text')).contains(expressions[29]) |\
    lower(col('text')).contains(expressions[30]) |\
    lower(col('text')).contains(expressions[31]) |\
    lower(col('text')).contains(expressions[32]) |\
    lower(col('text')).contains(expressions[33]) |\
    lower(col('text')).contains(expressions[34]) |\
    lower(col('text')).contains(expressions[35]) |\
    lower(col('text')).contains(expressions[36]) |\
    lower(col('text')).contains(expressions[37]) |\
    lower(col('text')).contains(expressions[38]) |\
    lower(col('text')).contains(expressions[39]) |\
    lower(col('text')).contains(expressions[40])
)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[16], line 106
#      61 expressions = [
#      62     'ameaça',
#      63     'aporofobia',
#    (...)
#     102     'xenofobia'
#     103 ]
#     105 # Create a filtered DataFrame
# --> 106 filtered_tweets_spark_df = tweets_spark_df.filter(
#     107     array_contains('entities.hashtags.text', hashtags[0]) |\
#     108     array_contains('entities.hashtags.text', hashtags[1]) |\
#     109     array_contains('entities.hashtags.text', hashtags[2]) |\
#     110     array_contains('entities.hashtags.text', hashtags[3]) |\
#     111     array_contains('entities.hashtags.text', hashtags[4]) |\
#     112     array_contains('entities.hashtags.text', hashtags[5]) |\
#     113     array_contains('entities.hashtags.text', hashtags[6]) |\
#     114     array_contains('entities.hashtags.text', hashtags[7]) |\
#     115     array_contains('entities.hashtags.text', hashtags[8]) |\
#     116     array_contains('entities.hashtags.text', hashtags[9]) |\
#     117     array_contains('entities.hashtags.text', hashtags[10]) |\
#     118     array_contains('entities.hashtags.text', hashtags[11]) |\
#     119     array_contains('entities.hashtags.text', hashtags[12]) |\
#     120     array_contains('entities.hashtags.text', hashtags[13]) |\
#     121     array_contains('entities.hashtags.text', hashtags[14]) |\
#     122     array_contains('entities.hashtags.text', hashtags[15]) |\
#     123     array_contains('entities.hashtags.text', hashtags[16]) |\
#     124     array_contains('entities.hashtags.text', hashtags[17]) |\
#     125     array_contains('entities.hashtags.text', hashtags[18]) |\
#     126     array_contains('entities.hashtags.text', hashtags[19]) |\
#     127     array_contains('entities.hashtags.text', hashtags[20]) |\
#     128     array_contains('entities.hashtags.text', hashtags[21]) |\
#     129     array_contains('entities.hashtags.text', hashtags[22]) |\
#     130     array_contains('entities.hashtags.text', hashtags[23]) |\
#     131     array_contains('entities.hashtags.text', hashtags[24]) |\
#     132     array_contains('entities.hashtags.text', hashtags[25]) |\
#     133     array_contains('entities.hashtags.text', hashtags[26]) |\
#     134     array_contains('entities.hashtags.text', hashtags[27]) |\
#     135     array_contains('entities.hashtags.text', hashtags[28]) |\
#     136     array_contains('entities.hashtags.text', hashtags[29]) |\
#     137     array_contains('entities.hashtags.text', hashtags[30]) |\
#     138     array_contains('entities.hashtags.text', hashtags[31]) |\
#     139     array_contains('entities.hashtags.text', hashtags[32]) |\
#     140     array_contains('entities.hashtags.text', hashtags[33]) |\
#     141     array_contains('entities.hashtags.text', hashtags[34]) |\
#     142     array_contains('entities.hashtags.text', hashtags[35]) |\
#     143     array_contains('entities.hashtags.text', hashtags[36]) |\
#     144     array_contains('entities.hashtags.text', hashtags[37]) |\
#     145     array_contains('entities.hashtags.text', hashtags[38]) |\
#     146     array_contains('entities.hashtags.text', hashtags[39]) |\
#     147     array_contains('entities.hashtags.text', hashtags[40]) |\
#     148     array_contains('entities.hashtags.text', hashtags[41]) |\
#     149     array_contains('entities.hashtags.text', hashtags[42]) |\
#     150     array_contains('entities.hashtags.text', hashtags[43]) |\
#     151     array_contains('entities.hashtags.text', hashtags[44]) |\
#     152     array_contains('entities.hashtags.text', hashtags[45]) |\
#     153     array_contains('entities.hashtags.text', hashtags[46]) |\
#     154     array_contains('entities.hashtags.text', hashtags[47]) |\
#     155     array_contains('entities.hashtags.text', hashtags[48]) |\
#     156     array_contains('entities.hashtags.text', hashtags[49]) |\
#     157     array_contains('entities.hashtags.text', hashtags[50]) |\
#     158     array_contains('entities.hashtags.text', hashtags[51]) |\
#     159     array_contains('entities.hashtags.text', hashtags[52]) |\
#     160     array_contains('entities.hashtags.text', hashtags[53]) |\
#     161     array_contains('entities.hashtags.text', hashtags[54]) |\
#     162     array_contains('entities.hashtags.text', hashtags[55]) |\
#     163     lower(col('text')).contains(expressions[0]) |\
#     164     lower(col('text')).contains(expressions[1]) |\
#     165     lower(col('text')).contains(expressions[2]) |\
#     166     lower(col('text')).contains(expressions[3]) |\
#     167     lower(col('text')).contains(expressions[4]) |\
#     168     lower(col('text')).contains(expressions[5]) |\
#     169     lower(col('text')).contains(expressions[6]) |\
#     170     lower(col('text')).contains(expressions[7]) |\
#     171     lower(col('text')).contains(expressions[8]) |\
#     172     lower(col('text')).contains(expressions[9]) |\
#     173     lower(col('text')).contains(expressions[10]) |\
#     174     lower(col('text')).contains(expressions[11]) |\
#     175     lower(col('text')).contains(expressions[12]) |\
#     176     lower(col('text')).contains(expressions[13]) |\
#     177     lower(col('text')).contains(expressions[14]) |\
#     178     lower(col('text')).contains(expressions[15]) |\
#     179     lower(col('text')).contains(expressions[16]) |\
#     180     lower(col('text')).contains(expressions[17]) |\
#     181     lower(col('text')).contains(expressions[18]) |\
#     182     lower(col('text')).contains(expressions[19]) |\
#     183     lower(col('text')).contains(expressions[20]) |\
#     184     lower(col('text')).contains(expressions[21]) |\
#     185     lower(col('text')).contains(expressions[22]) |\
#     186     lower(col('text')).contains(expressions[23]) |\
#     187     lower(col('text')).contains(expressions[24]) |\
#     188     lower(col('text')).contains(expressions[25]) |\
#     189     lower(col('text')).contains(expressions[26]) |\
#     190     lower(col('text')).contains(expressions[27]) |\
#     191     lower(col('text')).contains(expressions[28]) |\
#     192     lower(col('text')).contains(expressions[29]) |\
#     193     lower(col('text')).contains(expressions[30]) |\
#     194     lower(col('text')).contains(expressions[31]) |\
#     195     lower(col('text')).contains(expressions[32]) |\
#     196     lower(col('text')).contains(expressions[33]) |\
#     197     lower(col('text')).contains(expressions[34]) |\
#     198     lower(col('text')).contains(expressions[35]) |\
#     199     lower(col('text')).contains(expressions[36]) |\
#     200     lower(col('text')).contains(expressions[37]) |\
#     201     lower(col('text')).contains(expressions[38]) |\
#     202     lower(col('text')).contains(expressions[39]) |\
#     203     lower(col('text')).contains(expressions[40])
#     204 )
#
# File ~\anaconda3\envs\Env20240401\Lib\site-packages\pyspark\sql\dataframe.py:3138, in DataFrame.filter(self, condition)
#    3136     jdf = self._jdf.filter(condition)
#    3137 elif isinstance(condition, Column):
# -> 3138     jdf = self._jdf.filter(condition._jc)
#    3139 else:
#    3140     raise PySparkTypeError(
#    3141         error_class="NOT_COLUMN_OR_STR",
#    3142         message_parameters={"arg_name": "condition", "arg_type": type(condition).__name__},
#    3143     )
#
# File ~\anaconda3\envs\Env20240401\Lib\site-packages\py4j\java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~\anaconda3\envs\Env20240401\Lib\site-packages\pyspark\errors\exceptions\captured.py:175, in capture_sql_exception.<locals>.deco(*a, **kw)
#     171 converted = convert_exception(e.java_exception)
#     172 if not isinstance(converted, UnknownException):
#     173     # Hide where the exception came from that shows a non-Pythonic
#     174     # JVM exception message.
# --> 175     raise converted from None
#     176 else:
#     177     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `entities`.`hashtags`.`text` cannot be resolved. Did you mean one of the following? [`data`, `includes`, `errors`].;
# 'Filter ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((array_contains('entities.hashtags.text, acolhimento) OR array_contains('entities.hashtags.text, Acolhimento)) OR array_contains('entities.hashtags.text, ACOLHIMENTO)) OR array_contains('entities.hashtags.text, aporofobia)) OR array_contains('entities.hashtags.text, Aporofobia)) OR array_contains('entities.hashtags.text, APOROFOBIA)) OR array_contains('entities.hashtags.text, brasilvaivirarvenezuela)) OR array_contains('entities.hashtags.text, Brasilvaivirarvenezuela)) OR array_contains('entities.hashtags.text, BrasilVaiVirarVenezuela)) OR array_contains('entities.hashtags.text, BRASILVAIVIRARVENEZUELA)) OR array_contains('entities.hashtags.text, crisehumanitária)) OR array_contains('entities.hashtags.text, Crisehumanitária)) OR array_contains('entities.hashtags.text, CriseHumanitária)) OR array_contains('entities.hashtags.text, CRISEHUMANITÁRIA)) OR array_contains('entities.hashtags.text, crisevenezuelana)) OR array_contains('entities.hashtags.text, Crisevenezuelana)) OR array_contains('entities.hashtags.text, CriseVenezuelana)) OR array_contains('entities.hashtags.text, CRISEVENEZUELANA)) OR array_contains('entities.hashtags.text, Discriminação)) OR array_contains('entities.hashtags.text, discriminação)) OR array_contains('entities.hashtags.text, DISCRIMINAÇÃO)) OR array_contains('entities.hashtags.text, estereótipo)) OR array_contains('entities.hashtags.text, Estereótipo)) OR array_contains('entities.hashtags.text, ESTEREÓTIPO)) OR array_contains('entities.hashtags.text, fronteira)) OR array_contains('entities.hashtags.text, Fronteira)) OR array_contains('entities.hashtags.text, FRONTEIRA)) OR array_contains('entities.hashtags.text, migrantes)) OR array_contains('entities.hashtags.text, Migrantes)) OR array_contains('entities.hashtags.text, MIGRANTES)) OR array_contains('entities.hashtags.text, preconceito)) OR array_contains('entities.hashtags.text, Preconceito)) OR array_contains('entities.hashtags.text, PRECONCEITO)) OR array_contains('entities.hashtags.text, refugiados)) OR array_contains('entities.hashtags.text, Refugiados)) OR array_contains('entities.hashtags.text, REFUGIADOS)) OR array_contains('entities.hashtags.text, roraizuela)) OR array_contains('entities.hashtags.text, Roraizuela)) OR array_contains('entities.hashtags.text, RORAIZUELA)) OR array_contains('entities.hashtags.text, venebrasil)) OR array_contains('entities.hashtags.text, Venebrasil)) OR array_contains('entities.hashtags.text, VeneBrasil)) OR array_contains('entities.hashtags.text, VENEBRASIL)) OR array_contains('entities.hashtags.text, venezuelanosnobrasil)) OR array_contains('entities.hashtags.text, Venezuelanosnobrasil)) OR array_contains('entities.hashtags.text, VenezuelanosNoBrasil)) OR array_contains('entities.hashtags.text, VENEZUELANOSNOBRASIL)) OR array_contains('entities.hashtags.text, venezuraima)) OR array_contains('entities.hashtags.text, Venezuraima)) OR array_contains('entities.hashtags.text, VENEZURAIMA)) OR array_contains('entities.hashtags.text, violência)) OR array_contains('entities.hashtags.text, Violência)) OR array_contains('entities.hashtags.text, VIOLÊNCIA)) OR array_contains('entities.hashtags.text, xenofobia)) OR array_contains('entities.hashtags.text, Xenofobia)) OR array_contains('entities.hashtags.text, XENOFOBIA)) OR Contains(lower('text), ameaça)) OR Contains(lower('text), aporofobia)) OR Contains(lower('text), carga)) OR Contains(lower('text), conflito)) OR Contains(lower('text), crise)) OR Contains(lower('text), delinquência)) OR Contains(lower('text), desconfiança)) OR Contains(lower('text), desemprego)) OR Contains(lower('text), desigualdade)) OR Contains(lower('text), desordem)) OR Contains(lower('text), direitos)) OR Contains(lower('text), discriminação)) OR Contains(lower('text), estigma)) OR Contains(lower('text), estrangeiro)) OR Contains(lower('text), exclusão)) OR Contains(lower('text), fronteira)) OR Cont ...
# +- Relation [data#734,errors#735,includes#736] json
